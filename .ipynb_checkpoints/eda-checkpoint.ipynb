# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv")

# %%
print(df.corr()['CGPA'].sort_values(ascending=False))
# Out:
# CGPA            1.000000
# marks           0.868495
# sleep_hours     0.620140
# study_hours     0.506608
# attendance      0.421862
# stress_level   -0.170245
# Name: CGPA, dtype: float64
